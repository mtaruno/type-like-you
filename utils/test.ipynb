# %%
from parse import get_conversation

conversation = get_conversation(50, "/Users/matthewtaruno/Library/Mobile Documents/com~apple~CloudDocs/Dev/type-like-you/data/bryan.txt", True)

# %%
conversation
# Out:
# [{'date': '03/02/19',
#   'time': '03.06.20',
#   'name': 'Bryan Widjaja',
#   'message': '\u200eMessages and calls are end-to-end encrypted. No one outside of this chat, not even WhatsApp, can read or listen to them.'},
#  {'date': '03/02/19',
#   'time': '03.06.20',
#   'name': 'Bryan Widjaja',
#   'message': "\u200eBryan changed their phone number. You're currently chatting with their new number"},
#  {'date': '27/07/23',
#   'time': '01.13.46',
#   'name': 'Bryan Widjaja',
#   'message': 'Yo whats good man this is bryan'},
#  {'date': '27/07/23',
#   'time': '01.13.49',
#   'name': 'Bryan Widjaja',
#   'message': 'Lu lg di redmond?'},
#  {'date': '27/07/23',
#   'time': '01.55.04',
#   'name': 'Matthew Taruno',
#   'message': 'Yup I live in Bellevue currently'},
#  {'date': '27/07/23',
#   'time': '01.55.09',
#   'name': 'Matthew Taruno',
#   'message': 'Belred'},
#  {'date': '27/07/23',
#   'time': '01.55.28',
#   'name': 'Matthew Taruno',
# ...

# %%
len(conversation)
# Out:
# 426
